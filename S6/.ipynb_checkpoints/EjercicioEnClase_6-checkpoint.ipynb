# %% [markdown]
# # Ejercicio en clase 6
#
# ##### Dataset de Peajes (Exploración, Limpieza, Combinación, visualización en mapa)
#
# https://www.kaggle.com/datasets/martinaltamar/historico-peajes-colombia-trafico-y-recaudo
#
# https://geoportal.dane.gov.co/servicios/descarga-y-metadatos/datos-geoestadisticos/?cod=4
#
#
# Usando la información de los siguientes enlaces:
#
# Dataset de Kaggle: Historico Peajes Colombia - Tráfico y Recaudo
# Datos Geoespaciales del DANE: Descarga y Metadatos - Datos Geoestadísticos de Colombia
#
# Tu tarea es crear un mapa interactivo donde se puedan visualizar los peajes registrados en Colombia. Utiliza los datos proporcionados en el dataset de Kaggle para obtener la información relevante sobre los peajes, como su ubicación geoespacial y otros atributos pertinentes. Luego, utiliza los datos geoespaciales del DANE para representar correctamente la geografía de Colombia en el mapa.
#
# Puedes hacer uso de la biblioteca Folium en Python para la visualización del mapa interactivo. Asegúrate de incluir marcadores para cada peaje con información relevante que permita a los usuarios explorar los detalles de cada ubicación de peaje.
#
# Además, considera utilizar colores o tamaños de marcadores para resaltar características específicas de los peajes, como la tarifa

# %% [markdown]
# ## Usando Folium

# %% [markdown]
# ##### 💡 Recuerde instalar la librería
#
# ### Referencias
#
# - https://github.com/python-visualization/folium
# - https://python-visualization.github.io/folium/
# - https://nbviewer.org/github/python-visualization/folium/tree/main/examples/

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\carlos\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: requests in c:\users\carlos\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: numpy in c:\users\carlos\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\carlos\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\carlos\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\carlos\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\carlos\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\carlos\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\carlos\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\carlos\anaconda3\lib\site-packages (from requests->folium) (2.0.4)

# %%
import pandas as pd
import folium

# Crear un DataFrame con las coordenadas geográficas de las ciudades principales de Colombia
data = {
    'City': ['SOACHA', 'Medellín', 'Cali', 'Barranquilla', 'Cartagena'],
    'Latitude': [4.582774107987474, 6.2518402, 3.42158, 10.963889, 10.39972],
    'Longitude': [-74.21259167224173, -75.5635918, -76.5205, -74.796389, -75.51444]
}
df = pd.DataFrame(data)

# Crear un mapa de Folium centrado en Colombia
m = folium.Map(location=[4.6482837, -74.2478935], zoom_start=6)

# Agregar marcadores para cada ciudad al mapa
for index, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['City'],
        icon=folium.Icon(icon='cloud')  # Puedes cambiar el icono aquí
    ).add_to(m)

# Mostrar el mapa
m.save('map_colombia_cities.html')  # Guardar el mapa en un archivo HTML

#m.show_in_browser()

# %%
data
# Out:
# {'City': ['SOACHA', 'Medellín', 'Cali', 'Barranquilla', 'Cartagena'],
#  'Latitude': [4.582774107987474, 6.2518402, 3.42158, 10.963889, 10.39972],
#  'Longitude': [-74.21259167224173,
#   -75.5635918,
#   -76.5205,
#   -74.796389,
#   -75.51444]}

# %%
data = pd.read_csv('archive/DatasetCoordenadas.csv', sep=',')
df = pd.DataFrame(data)

# Crear un mapa de Folium centrado en Colombia
m = folium.Map(location=[4.6482837, -74.2478935], zoom_start=6)

# Agregar marcadores para cada ciudad al mapa
for index, row in df.iterrows():
    folium.Marker(
        location=[row['Latitud'], row['Longitud']],
        popup=row['Ciudad'],
        icon =folium.Icon(icon='cloud')  # Puedes cambiar el icono aquí
    ).add_to(m)

# Mostrar el mapa
#m.save('map_colombia_cities_2.html')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Ciudad    327 non-null    object
#  1   Latitud   327 non-null    float64
#  2   Longitud  327 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 7.8+ KB

# %% [markdown]
# # Mapa con marcadores:

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones
folium.Marker([4.60971, -74.08175], popup='Bogotá').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín').add_to(mapa)
folium.Marker([10.39105, -75.47971], popup='Cartagena').add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_marcadores.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9cc2e012650e98079f7e094e985b928 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9cc2e012650e98079f7e094e985b928&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9cc2e012650e98079f7e094e985b928 = L.map(
#                 &quot;map_a9cc2e012650e98079f7e094e985b928&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39d823d3c1c2add37647c8d3409afd92 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9cc2e012650e98079f7e094e985b928);
#
#
#             var marker_ca5d769541a956f12c2a2521ed482cfe = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_a9cc2e012650e98079f7e094e985b928);
#
#
#         var popup_5e97ac8da96f005acd7843616cf2c3fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65b40f597ded3e05627cff5060762329 = $(`&lt;div id=&quot;html_65b40f597ded3e05627cff5060762329&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_5e97ac8da96f005acd7843616cf2c3fc.setContent(html_65b40f597ded3e05627cff5060762329);
#
#
#
#         marker_ca5d769541a956f12c2a2521ed482cfe.bindPopup(popup_5e97ac8da96f005acd7843616cf2c3fc)
#         ;
#
#
#
#
#             var marker_0854a1e20937260803edc673fb344e7c = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_a9cc2e012650e98079f7e094e985b928);
#
#
#         var popup_fdd970b17ad27366bb5522d29a8164e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5a94e7413872cb8ac4a07952159b487 = $(`&lt;div id=&quot;html_c5a94e7413872cb8ac4a07952159b487&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_fdd970b17ad27366bb5522d29a8164e7.setContent(html_c5a94e7413872cb8ac4a07952159b487);
#
#
#
#         marker_0854a1e20937260803edc673fb344e7c.bindPopup(popup_fdd970b17ad27366bb5522d29a8164e7)
#         ;
#
#
#
#
#             var marker_d6644ff93286804f7ed07a760a64a631 = L.marker(
#                 [10.39105, -75.47971],
#                 {}
#             ).addTo(map_a9cc2e012650e98079f7e094e985b928);
#
#
#         var popup_4d1829679d48d8d73f9af256921dd263 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e01408accf0691d563840e55c028e41 = $(`&lt;div id=&quot;html_6e01408accf0691d563840e55c028e41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cartagena&lt;/div&gt;`)[0];
#                 popup_4d1829679d48d8d73f9af256921dd263.setContent(html_6e01408accf0691d563840e55c028e41);
#
#
#
#         marker_d6644ff93286804f7ed07a760a64a631.bindPopup(popup_4d1829679d48d8d73f9af256921dd263)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Mapa de calor:

# %%
import folium
from folium.plugins import HeatMap

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Datos de ejemplo con ubicaciones y pesos
datos = [[4.60971, -74.08175, 10], [6.24420, -75.58120, 5], [10.39105, -75.47971, 15]]

# Agregar el mapa de calor con los datos
HeatMap(datos).add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_calor.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_706ad35d81658bb1f620789f3e218be1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_706ad35d81658bb1f620789f3e218be1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_706ad35d81658bb1f620789f3e218be1 = L.map(
#                 &quot;map_706ad35d81658bb1f620789f3e218be1&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b70eb54e3104072f0a9073677b7c34a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_706ad35d81658bb1f620789f3e218be1);
#
#
#             var heat_map_73e0924464249683d04ebdb842c6f10f = L.heatLayer(
#                 [[4.60971, -74.08175, 10], [6.2442, -75.5812, 5], [10.39105, -75.47971, 15]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_706ad35d81658bb1f620789f3e218be1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Mapa con polígonos:

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Datos de ejemplo con coordenadas de los vértices de un polígono
vertices = [[4.5, -74.0], [4.7, -74.0], [4.7, -73.8], [4.5, -73.8]]

# Agregar un polígono al mapa
folium.Polygon(locations=vertices, color='blue', fill=True, fill_color='blue').add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_poligono.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8827daacccfc74e7139c08570ac58c60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8827daacccfc74e7139c08570ac58c60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8827daacccfc74e7139c08570ac58c60 = L.map(
#                 &quot;map_8827daacccfc74e7139c08570ac58c60&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_715affe3fc114d90e303096e7679974e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8827daacccfc74e7139c08570ac58c60);
#
#
#             var polygon_e85c8721d91e742f1dfde1c6a7fdb578 = L.polygon(
#                 [[4.5, -74.0], [4.7, -74.0], [4.7, -73.8], [4.5, -73.8]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8827daacccfc74e7139c08570ac58c60);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones con contenido personalizado para el popup
folium.Marker([4.60971, -74.08175], popup='Bogotá - Capital de Colombia').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín - Ciudad de la eterna primavera').add_to(mapa)
folium.Marker([10.39105, -75.47971], popup='Cartagena - Ciudad amurallada').add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_918af2cb782fdb02d42e08b58eaa3001 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_918af2cb782fdb02d42e08b58eaa3001&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_918af2cb782fdb02d42e08b58eaa3001 = L.map(
#                 &quot;map_918af2cb782fdb02d42e08b58eaa3001&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_480442202d83c2a094415a73ce5f9b07 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_918af2cb782fdb02d42e08b58eaa3001);
#
#
#             var marker_c0bade3835fa6525af56da659c41c3cc = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_918af2cb782fdb02d42e08b58eaa3001);
#
#
#         var popup_6ebd8ed680ce0cd69ed907d5502d414c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c078a9cca1c86da54820ddcfe552e06 = $(`&lt;div id=&quot;html_7c078a9cca1c86da54820ddcfe552e06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá - Capital de Colombia&lt;/div&gt;`)[0];
#                 popup_6ebd8ed680ce0cd69ed907d5502d414c.setContent(html_7c078a9cca1c86da54820ddcfe552e06);
#
#
#
#         marker_c0bade3835fa6525af56da659c41c3cc.bindPopup(popup_6ebd8ed680ce0cd69ed907d5502d414c)
#         ;
#
#
#
#
#             var marker_20af1c5eb8bb4b9ecee5667b8419df13 = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_918af2cb782fdb02d42e08b58eaa3001);
#
#
#         var popup_4216c4317e7ebced793f721da749eb46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29e2dd54c4e1122d0a73e9822b9fb9a7 = $(`&lt;div id=&quot;html_29e2dd54c4e1122d0a73e9822b9fb9a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín - Ciudad de la eterna primavera&lt;/div&gt;`)[0];
#                 popup_4216c4317e7ebced793f721da749eb46.setContent(html_29e2dd54c4e1122d0a73e9822b9fb9a7);
#
#
#
#         marker_20af1c5eb8bb4b9ecee5667b8419df13.bindPopup(popup_4216c4317e7ebced793f721da749eb46)
#         ;
#
#
#
#
#             var marker_ef72513cc41babb138c1e3ef4d704cc7 = L.marker(
#                 [10.39105, -75.47971],
#                 {}
#             ).addTo(map_918af2cb782fdb02d42e08b58eaa3001);
#
#
#         var popup_3148a241f18fe62706ee2e847c86f4cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1bbcdb61ec61fd532a1025e2084f2b2 = $(`&lt;div id=&quot;html_c1bbcdb61ec61fd532a1025e2084f2b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cartagena - Ciudad amurallada&lt;/div&gt;`)[0];
#                 popup_3148a241f18fe62706ee2e847c86f4cf.setContent(html_c1bbcdb61ec61fd532a1025e2084f2b2);
#
#
#
#         marker_ef72513cc41babb138c1e3ef4d704cc7.bindPopup(popup_3148a241f18fe62706ee2e847c86f4cf)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar un marcador con un icono predefinido (en este caso, un ícono de estrella)
folium.Marker([4.60971, -74.08175], popup='Bogotá', icon=folium.Icon(icon='star')).add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87df2082a5f75ce10b86633ab7d3f02e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87df2082a5f75ce10b86633ab7d3f02e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87df2082a5f75ce10b86633ab7d3f02e = L.map(
#                 &quot;map_87df2082a5f75ce10b86633ab7d3f02e&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c5adb1d959a81b7804604ea06f9fe0b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_87df2082a5f75ce10b86633ab7d3f02e);
#
#
#             var marker_56b57a2fc60829b29f74db0635e09fa4 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_87df2082a5f75ce10b86633ab7d3f02e);
#
#
#             var icon_61916642929a8524c1e2869ccb9a4969 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_56b57a2fc60829b29f74db0635e09fa4.setIcon(icon_61916642929a8524c1e2869ccb9a4969);
#
#
#         var popup_90d6b916bc236a963e4dc716b9772055 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5abc1c7e095e1b98ed925fc3d0dd0f0d = $(`&lt;div id=&quot;html_5abc1c7e095e1b98ed925fc3d0dd0f0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_90d6b916bc236a963e4dc716b9772055.setContent(html_5abc1c7e095e1b98ed925fc3d0dd0f0d);
#
#
#
#         marker_56b57a2fc60829b29f74db0635e09fa4.bindPopup(popup_90d6b916bc236a963e4dc716b9772055)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Definir la ruta del archivo de imagen del icono personalizado
ruta_icono_personalizado = 'dolar.png'

# Crear un objeto Icon con el icono personalizado
icono_personalizado = folium.CustomIcon(icon_image=ruta_icono_personalizado, icon_size=(30, 30))

# Agregar un marcador con el icono personalizado
folium.Marker([4.60971, -74.08175], popup='Bogotá', icon=icono_personalizado).add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fd4c5f620f945f8d58773b264ba4e44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fd4c5f620f945f8d58773b264ba4e44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fd4c5f620f945f8d58773b264ba4e44 = L.map(
#                 &quot;map_1fd4c5f620f945f8d58773b264ba4e44&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80f6bea6f9bb362ff34b27204ae0ae36 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fd4c5f620f945f8d58773b264ba4e44);
#
#
#             var marker_472cfdd6e51dff45249d5ed8c1286ab6 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_1fd4c5f620f945f8d58773b264ba4e44);
#
#
#         var custom_icon_4d299b306b26fe5b952bd20a8542cbba = L.icon({&quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_472cfdd6e51dff45249d5ed8c1286ab6.setIcon(custom_icon_4d299b306b26fe5b952bd20a8542cbba);
#
#
#         var popup_5d6d5ff05ce8eb5cd70d5d60a72bde9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea14b242b74e1dd949848dc73949467f = $(`&lt;div id=&quot;html_ea14b242b74e1dd949848dc73949467f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_5d6d5ff05ce8eb5cd70d5d60a72bde9f.setContent(html_ea14b242b74e1dd949848dc73949467f);
#
#
#
#         marker_472cfdd6e51dff45249d5ed8c1286ab6.bindPopup(popup_5d6d5ff05ce8eb5cd70d5d60a72bde9f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones
folium.Marker([4.60971, -74.08175], popup='Bogotá').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín').add_to(mapa)

# Coordenadas de los puntos para trazar la línea
coordenadas_linea = [[4.60971, -74.08175], [6.24420, -75.58120]]

# Agregar la línea que conecta los dos puntos
folium.PolyLine(locations=coordenadas_linea, color='blue').add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edf32e138453fb7f0856401da052d966 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edf32e138453fb7f0856401da052d966&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edf32e138453fb7f0856401da052d966 = L.map(
#                 &quot;map_edf32e138453fb7f0856401da052d966&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4724b55efb6854adb1157a06e91bceef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_edf32e138453fb7f0856401da052d966);
#
#
#             var marker_53aa3929e9b63d51ff1a8f981f6ab63e = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_edf32e138453fb7f0856401da052d966);
#
#
#         var popup_a354287e05191bd5ec0f12b8dc319210 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e12d2de2e4224945b05ae8a12bdba994 = $(`&lt;div id=&quot;html_e12d2de2e4224945b05ae8a12bdba994&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_a354287e05191bd5ec0f12b8dc319210.setContent(html_e12d2de2e4224945b05ae8a12bdba994);
#
#
#
#         marker_53aa3929e9b63d51ff1a8f981f6ab63e.bindPopup(popup_a354287e05191bd5ec0f12b8dc319210)
#         ;
#
#
#
#
#             var marker_a6cf22c257ae054f998341d999c8946a = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_edf32e138453fb7f0856401da052d966);
#
#
#         var popup_7e40159b35b87ecefadefe4dfefedc61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9c54669ea6ddded42d53e47891f559e = $(`&lt;div id=&quot;html_f9c54669ea6ddded42d53e47891f559e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_7e40159b35b87ecefadefe4dfefedc61.setContent(html_f9c54669ea6ddded42d53e47891f559e);
#
#
#
#         marker_a6cf22c257ae054f998341d999c8946a.bindPopup(popup_7e40159b35b87ecefadefe4dfefedc61)
#         ;
#
#
#
#
#             var poly_line_6514a3ecbbb0452eb57d041c8f064d04 = L.polyline(
#                 [[4.60971, -74.08175], [6.2442, -75.5812]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_edf32e138453fb7f0856401da052d966);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
